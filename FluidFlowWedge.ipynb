# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import numba

# %%
N = 96, 64
L = 15.0, 10.0
u = np.zeros(N)

# %%
# Arrays for setting the initial conditions
x = np.linspace(-0.5*L[0], 0.5*L[0], N[0])
y = np.linspace(-0.5*L[1], 0.5*L[1], N[1])
xv, yv = np.meshgrid(x, y, sparse=False, indexing='ij')

# %% [markdown]
# We'll define the type of boundary points as faces or edges using this labeling:
# $$
# \begin{pmatrix}
# 0 & 1 & 2 \\
# 3 &   & 4 \\
# 5 & 6 & 7 \\
# \end{pmatrix}
# $$
# For example, a boundary point with type 7 is a lower right corner,
# with fluid flow on the bottom and left.

# %%
TOP, BOTTOM, LEFT, RIGHT = 1, 6, 3, 4
TOPL, TOPR, BOTL, BOTR = 0, 2, 5, 7

# %%
# Make shape for boundary: a wedge from (668,412) to (868,612), inclusive
top, bottom, left, right = 40, 24, 40, 56 
bpoints = []
btype = []
for i in range(left+1, right):
    bpoints.append((i, bottom)); btype.append(BOTTOM)
for j in range(bottom+1, top):
    bpoints.append((right, j)); btype.append(RIGHT)
bpoints.append((right, top)); btype.append(TOPR)
bpoints.append((left, bottom)); btype.append(BOTL)
bpoints.append((right, bottom)); btype.append(BOTR)
for i in range(right-left):
    bpoints.append((left+i,bottom+1+i)); btype.append(TOPL)
bpoints = np.array(bpoints)
btype = np.array(btype)
mask = np.ones(N, dtype=np.uint8)
for i,j in bpoints:
    mask[i,j] = 0

# %%
@numba.jit(nopython=True)
def smooth(u, mask):
    for i in range(1, N[0]-1):
        for j in range(1 + i % 2, N[1]-1, 2):
            u[i,j] = mask[i,j] * 0.25 * (u[i+1,j] + u[i,j+1] + u[i-1,j] + u[i,j-1]) \
                   + (1-mask[i,j]) * u[i,j]
    for i in range(1, N[0]-1):
        for j in range(2 - i % 2, N[1]-1, 2):
            u[i,j] = mask[i,j] * 0.25 * (u[i+1,j] + u[i,j+1] + u[i-1,j] + u[i,j-1]) \
                               + (1-mask[i,j]) * u[i,j]

# %%
@numba.jit(nopython=True)
def apply_bc(u):
    for icell in range(len(btype)):
        i, j = bpoints[icell]
        itype = btype[icell]
        if (itype == TOP):
            u[i,j] = u[i,j+2]
        elif (itype == BOTTOM):
            u[i,j] = u[i,j-2]
        elif (itype == LEFT):
            u[i,j] = u[i-2,j]
        elif (itype == RIGHT):
            u[i,j] = u[i+2,j]
        elif (itype == TOPL):
            u[i,j] = 0.5 * (u[i,j+2] + u[i-2,j])
        elif (itype == TOPR):
            u[i,j] = 0.5 * (u[i,j+2] + u[i+2,j])
        elif (itype == BOTL):
            u[i,j] = 0.5 * (u[i,j-2] + u[i-2,j])
        elif (itype == BOTR):
            u[i,j] = 0.5 * (u[i,j-2] + u[i+2,j])

# %%
@numba.jit(nopython=True)
def force():
    fx, fy = np.zeros(N), np.zeros(N)
    for icell in range(len(btype)):
        i, j = bpoints[icell]
        itype = btype[icell]
        if (itype == TOP):
            fy[i,j] += v[i,j+1]**2
        elif (itype == BOTTOM):
            fy[i,j] -= v[i,j-1]**2
        elif (itype == LEFT):
            fx[i,j] -= v[i-1,j]**2
        elif (itype == RIGHT):
            fx[i,j] += v[i+1,j]**2
        elif (itype == TOPL):
            fx[i,j] -= v[i-1,j]**2
            fy[i,j] += v[i,j+1]**2
        elif (itype == TOPR):
            fx[i,j] += v[i+1,j]**2
            fy[i,j] += v[i,j+1]**2
        elif (itype == BOTL):
            fx[i,j] -= v[i-1,j]**2
            fy[i,j] -= v[i,j-1]**2
        elif (itype == BOTR):
            fx[i,j] += v[i+1,j]**2
            fy[i,j] -= v[i,j-1]**2
    return fx, fy

# %%
# Initial conditions (uniform flow to the right)
u[:,:] = -xv

# %%
apply_bc(u)
for i in range(1000):
    smooth(u, mask)
    apply_bc(u)

# %%
plt.imshow(u.transpose(), origin="lower", interpolation='nearest'); plt.gcf().set_size_inches(15,10)

# %%
dx, dy = np.gradient(u)
for i in range(right-left):
    dx[left+i:right+1, bottom+i+1] = 0
    dy[left+i:right+1, bottom+i+1] = 0
dx[left:right+1, bottom] = 0
dy[left:right+1, bottom] = 0
v = np.sqrt(dx**2 + dy**2)

# %%
plt.quiver(xv, yv, -dx, -dy, v); plt.gcf().set_size_inches(15,10)

# %%
plt.imshow(v.transpose(), origin="lower", interpolation='nearest'); plt.gcf().set_size_inches(15,10)

# %%
fx, fy = force()

# %%
plt.quiver(xv, yv, fx, fy, scale=2.); plt.gcf().set_size_inches(15,10)

# %%
fx.sum(), fy.sum()
# Out:
# (-0.020300742265250526, -0.11320898413510819)
